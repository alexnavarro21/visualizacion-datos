# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Datos.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
r1 = df[['Economy (GDP per Capita)','Happiness Score']].corr()
print(f'La relacion entre el ingreso y la felicidad mundial es positivo y tiene una intensidad de: {r1.iloc[0,1].round(2)}')
# Out:
# La relacion entre el ingreso y la felicidad mundial es positivo y tiene una intensidad de: 0.78

# %%
# Visualizacón Nº1
sns.set_style('darkgrid')
sns.lmplot(data=df, x='Economy (GDP per Capita)', y='Happiness Score', scatter_kws={"color": 'gold'}, line_kws={'color':'purple'})
plt.title('Correlacion ingreso vs felicidad mundial')
plt.xlabel('Ingresos (GDP per capita)')
plt.ylabel('Nivel de felicidad')
plt.show()

# %% [markdown]
# **Qué:** El tipo de dataset son datos escalares (ingreso per cápita y nivel de felicidad mundial).
#
# **Por qué:** Mostrar la relación positiva entre el ingreso per cápita y el nivel de felicidad mundial.
#
# Tarea: Mostrar la correlación entre ingreso y felicidad.
# Acción: Visualizar la relación.
# Objetivo: Apreciar cómo el aumento del ingreso se asocia con mayor felicidad.
#
# **Cómo:** Se usan las siguientes codificaciones visuales: Encode (Align, Color (Hue)). La posición horizontal representa el ingreso per cápita, la posición vertical representa el nivel de felicidad, y el color diferencia los elementos (puntos dorados y línea morada).

# %%
# Visualizacón Nº2
r2 = df.head(10)
display(r2)
sns.barplot(data=r2, x='Happiness Rank', y='Country', hue='Region')
plt.title('Top 10 Países vs Rango de felicidad')
plt.xlabel('Rango de felicidad')
plt.ylabel('País')
plt.show()
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# **Qué:** El tipo de dataset son datos escalares (rango de felicidad y país).
#
# **Por qué:** Mostrar la distribución del rango de felicidad entre los 10 países con mayor puntaje.
#
# Tarea: Mostrar el rango de felicidad.
# Acción: Visualizar los países top 10.
# Objetivo: Apreciar cómo se distribuyen los países más felices y sus regiones.
#
# **Cómo:** Se usan las siguientes codificaciones visuales: Encode (Align, Color (Hue, Saturation)). La posición horizontal representa el rango de felicidad, la posición vertical representa el país, y el color diferencia las regiones geográficas de cada país.

# %%
r3 = df.groupby('Region')['Happiness Score'].mean().reset_index()
r3
# Out:
#                             Region  Happiness Score
# 0        Australia and New Zealand         7.285000
# 1       Central and Eastern Europe         5.332931
# 2                     Eastern Asia         5.626167
# 3      Latin America and Caribbean         6.144682
# 4  Middle East and Northern Africa         5.406900
# 5                    North America         7.273000
# 6                Southeastern Asia         5.317444
# 7                    Southern Asia         4.580857
# 8               Sub-Saharan Africa         4.202800
# 9                   Western Europe         6.689619

# %%
# Visualizacón Nº3
sns.barplot(data=r3,x='Region',y='Happiness Score', hue='Region', palette='mako')
plt.xticks(rotation=40, ha='right')
plt.title('Happiness Score por región')
plt.show()

# %% [markdown]
# **Qué:** El tipo de dataset son datos escalares (Happiness Score promedio por región).
#
# **Por qué:** Mostrar la comparación del nivel promedio de felicidad entre diferentes regiones del mundo.
#
# Tarea: Mostrar el promedio de Happiness Score por región.
# Acción: Visualizar las regiones.
# Objetivo: Apreciar cuáles regiones tienen mayor o menor nivel de felicidad promedio.
#
# **Cómo:** Se usan las siguientes codificaciones visuales: Encode (Align, Color (Hue, Saturation)). La posición horizontal representa la región, la posición vertical muestra el valor promedio de Happiness Score, y el color

# %%
# Visualizacón Nº4
factor_cols = [
    "Economy (GDP per Capita)", "Family", "Health (Life Expectancy)",
    "Freedom", "Trust (Government Corruption)", "Generosity", "Dystopia Residual"
]

r4 = df.nlargest(5, "Happiness Score").set_index("Country")[factor_cols]

r4_norm = (r4 - r4.min()) / (r4.max() - r4.min())

r4_norm.plot(kind='bar', stacked=True, figsize=(10,6), colormap='tab20')
plt.title('Factores normalizados en países top 5 de felicidad')
plt.ylabel('Valor normalizado')
plt.xlabel('País')
plt.legend(loc='upper left', bbox_to_anchor=(1.02, 1), ncol=1)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Qué:** El tipo de dataset son datos escalares (factores normalizados de felicidad por país).
#
# **Por qué:** Mostrar la composición y comparación de los factores que contribuyen a la felicidad en los países con mayor puntaje.
#
# Tarea: Mostrar los factores normalizados en los países top 5 de felicidad.
# Acción: Visualizar la composición de factores.
# Objetivo: Apreciar cómo se distribuyen y comparan los distintos factores entre los países más felices.
#
# **Cómo:** Se usan las siguientes codificaciones visuales: Encode (Align, Color (Hue, Saturation)). La posición horizontal representa el país, la posición vertical muestra el valor normalizado de cada factor, y el color diferencia cada factor en la barra

# %%
# Visualización Nº5

# Definir columnas de contribuciones
contrib_cols = [
    "Economy (GDP per Capita)",
    "Family",
    "Health (Life Expectancy)",
    "Freedom",
    "Trust (Government Corruption)",
    "Generosity"
]
df_top10 = df.head(10)
plt.stackplot(df_top10["Country"], 
              df_top10[contrib_cols].T, 
              labels=contrib_cols, alpha=0.8)

plt.legend(loc="upper left")
plt.title("Contribuciones al Happiness Score (Top 10 países)")
plt.xlabel("País")
plt.ylabel("Puntaje de felicidad (contribuciones)")
plt.xticks(rotation=45)
plt.legend(loc="center left", bbox_to_anchor=(1, 0.5))

plt.tight_layout()
plt.show()

# %% [markdown]
# **Qué:** Datos categóricos (países) y escalares (promedio de felicidad).
#
# **Por qué:** Mostrar la comparación de felicidad entre países.
#
# Tarea: Comparar niveles de felicidad.
#
# Acción: Las barras permiten contrastar valores de manera clara.
#
# Objetivo: Identificar qué países destacan en felicidad.
#
# **Cómo:** Barras verticales; posición X = país, altura = promedio.

# %%
years = np.arange(2010, 2021)
countries = df["Country"].unique()
data = []

np.random.seed(42)
for country in countries:
    base = df[df["Country"] == country][["Economy (GDP per Capita)", "Family", "Health (Life Expectancy)"]].mean().values
    for i, year in enumerate(years):
        vals = base + np.random.normal(0, 0.5, 3) * base * (1 + 0.03 * i)
        data.append([country, year] + list(vals))

df_time = pd.DataFrame(data, columns=["Country", "Year", "Economy", "Family", "Health"])
df_time
# Out:
#           Country  Year   Economy    Family    Health
# 0     Switzerland  2010  1.743343  1.256215  1.246307
# 1     Switzerland  2011  2.491877  1.186774  0.827912
# 2     Switzerland  2012  2.565365  1.898410  0.707182
# 3     Switzerland  2013  1.809451  1.008674  0.702474
# 4     Switzerland  2014  1.585736 -0.096405  0.032052
# ...           ...   ...       ...       ...       ...
# 1733         Togo  2016  0.322650  0.112638  0.198818
# 1734         Togo  2017  0.227549  0.205209  0.694276
# 1735         Togo  2018  0.315709  0.240588  0.195205
# 1736         Togo  2019  0.072740  0.145489  0.303786
# 1737         Togo  2020  0.062388  0.124004  0.358256
#
# [1738 rows x 5 columns]

# %%
# Visualizacón Nº6

df_time_region = df_time.merge(df[["Country", "Region"]], on="Country", how="left")

df_area = df_time_region.groupby(["Year", "Region"])[["Economy", "Family", "Health"]].mean().reset_index()

pivot = df_area.pivot(index="Year", columns="Region", values="Economy")

plt.figure(figsize=(12,7))
plt.stackplot(
    pivot.index,
    [pivot[region].fillna(0) for region in pivot.columns],
    labels=pivot.columns,
    alpha=0.85
)
plt.xlabel("Año")
plt.ylabel("Economy (GDP per Capita) promedio")
plt.title("Stacked Area Chart: Evolución de Economy por Región")
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1), ncol=1)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Qué:** El tipo de dataset son datos escalares (PIB promedio por región y año).
#
# **Por qué:** Mostrar la evolución del PIB promedio entre las distintas regiones del mundo a lo largo del tiempo.
#
# Tarea: Mostrar la evolución del PIB promedio por región.
# Acción: Visualizar el cambio a lo largo de los años.
# Objetivo: Apreciar cómo varía el PIB promedio en cada región y comparar tendencias.
#
# **Cómo:** Se usan las siguientes codificaciones visuales: Encode (Align, Color (Hue, Saturation)). La posición horizontal representa el año, la posición vertical muestra el PIB promedio, y el color diferencia cada región en el gráfico de áreas apiladas.

# %%
# Visualización Nº7
from scipy import stats

def gaussian_smooth(x, y, grid, sd):
    weights = np.transpose([stats.norm.pdf(grid, m, sd) for m in x])
    weights = weights / weights.sum(0)
    return (weights * y).sum(1)

# Prepara los datos reales de df_time por región
df_time_region = df_time.merge(df[["Country", "Region"]], on="Country", how="left")
df_area = df_time_region.groupby(["Year", "Region"])[["Economy"]].mean().reset_index()
pivot = df_area.pivot(index="Year", columns="Region", values="Economy")

x = pivot.index.values
grid = np.linspace(x.min()-4, x.max()+4, num=300)
y = [pivot[region].fillna(0).values for region in pivot.columns]
y_smoothed = [gaussian_smooth(x, y_, grid, 1) for y_ in y]

fig, ax = plt.subplots(figsize=(12, 7))
ax.stackplot(grid, y_smoothed, baseline="sym", labels=pivot.columns, alpha=0.85, cmap='Blues')
plt.xlabel("Año")
plt.ylabel("Economy (GDP per Capita) suavizado")
plt.title("Streamgraph: Evolución suavizada y centrada de Economy por Región")
plt.legend(loc="upper left", bbox_to_anchor=(1.02, 1), ncol=1)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Qué** El tipo de dataset son datos escalares.
#
# **Por qué:** Mostrar la evolución suavizada y centrada del PIB entre las distintas regiones del mundo a lo largo del tiempo.
#
# Tarea: Mostrar la evolución suavizada del PIB por región.
# Acción: Visualizar el cambio y las tendencias.
# Objetivo: Apreciar cómo varía el PIB suavizado en cada región y comparar patrones.
#
# **Cómo:** Se usan las siguientes codificaciones visuales: Encode (Align, Color (Hue, Saturation)). La posición horizontal representa el año, la posición vertical muestra el PIB suavizado, y el color diferencia cada región en el streamgraph.

# %%
# Visualizacion Nº8
factores=["Economy (GDP per Capita)","Family","Health (Life Expectancy)","Freedom",
          "Trust (Government Corruption)","Generosity","Dystopia Residual"]
top_10F=df.head(10)
heatmap_data = top_10F.set_index("Country")[factores]

plt.figure(figsize=(10,6))
sns.heatmap(heatmap_data, annot=True, cmap="RdBu", fmt=".2f")
plt.title("Factores de Felicidad - Top 10 Países más Felices")
plt.xlabel("Factores")
plt.ylabel("Países")
plt.show()

# %% [markdown]
# **Qué:** Datos escalares (PIB per cápita y felicidad).
#
# **Por qué:** Mostrar relación entre riqueza y felicidad.
#
# Tarea: Correlacionar dos variables.
#
# Acción: Los puntos permiten ver tendencias y dispersión.
#
# Objetivo: Apreciar si mayor PIB implica mayor felicidad.
#
# **Cómo:** Puntos; eje X = PIB, eje Y = felicidad.

# %%
# Visualizacion Nº9

import scipy

# Selecciona solo las columnas numéricas relevantes
features = [
    "Economy (GDP per Capita)", "Family", "Health (Life Expectancy)",
    "Freedom", "Trust (Government Corruption)", "Generosity", "Dystopia Residual"
]
df_numeric = df.set_index("Country")[features]

# Normaliza los datos para mejor agrupación
df_scaled = (df_numeric - df_numeric.mean()) / df_numeric.std()

# Cluster heatmap
sns.clustermap(
    df_scaled,
    method='ward',        # método de agrupación jerárquica
    metric='euclidean',   # distancia entre países
    cmap='mako',          # paleta de colores
    figsize=(12,10)
)
plt.title("Cluster Heatmap de Países por Similitud de Factores de Felicidad")
plt.show()

# %% [markdown]
# **Qué:** El tipo de dataset son datos escalares (factores normalizados de felicidad por país).
#
# **Por qué:** Mostrar la similitud y agrupación de países según sus factores de felicidad.
#
# Tarea: Mostrar la agrupación de países por similitud de factores.
# Acción: Visualizar los clusters y patrones.
# Objetivo: Apreciar cómo se agrupan los países y comparar sus perfiles de felicidad.
#
# **Cómo:** Se usan las siguientes codificaciones visuales: Encode (Align, Color (Hue, Saturation)). La posición representa los países y factores, el color indica el valor normalizado de cada factor, y las ramas muestran la agrupación jerárquica

# %%
# Visualizacion Nº10
sns.pairplot(df[[
    "Happiness Score",
    "Economy (GDP per Capita)",
    "Family",
    "Health (Life Expectancy)",
    "Freedom",
    "Trust (Government Corruption)",
    "Generosity"
]]) # matriz de scatterplot
plt.title('Variables cuantitativas')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Qué:** Datos escalares (años y felicidad promedio).
#
# **Por qué:** Mostrar evolución temporal.
#
# Tarea: Identificar tendencias a lo largo del tiempo.
#
# Acción: La línea evidencia la variación de la felicidad.
#
# Objetivo: Comprender cómo cambia la felicidad en el tiempo.
#
# **Cómo:** Línea; eje X = año, eje Y = promedio de felicidad.

# %%
# Visualizacion Nº11

from pandas.plotting import parallel_coordinates
from sklearn.cluster import KMeans

# Selecciona las columnas numéricas relevantes
features = [
    "Economy (GDP per Capita)", "Family", "Health (Life Expectancy)",
    "Freedom", "Trust (Government Corruption)", "Generosity", "Dystopia Residual"
]
df_numeric = df.set_index("Country")[features]

# Normaliza los datos
df_scaled = (df_numeric - df_numeric.mean()) / df_numeric.std()

# Usa KMeans para encontrar 10 países lo más distintos posible
kmeans = KMeans(n_clusters=10, random_state=42)
df_scaled['cluster'] = kmeans.fit_predict(df_scaled)
selected_countries = df_scaled.groupby('cluster').apply(lambda x: x.sample(1)).index.get_level_values(1)
df_selected = df.loc[df['Country'].isin(selected_countries), ['Country'] + features]

# Parallel coordinates plot
plt.figure(figsize=(14,6))
parallel_coordinates(df_selected, 'Country', colormap=plt.get_cmap("tab10"))
plt.title("Parallel Coordinates Plot: Relaciones multivariadas en 10 países distintos")
plt.ylabel("Valor normalizado")
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Qué:** El tipo de dataset son datos escalares (factores normalizados de felicidad en 10 países distintos).
#
# **Por qué:** Mostrar las relaciones multivariadas y comparar los perfiles de factores de felicidad entre países seleccionados por su diversidad.
#
# Tarea: Mostrar los factores normalizados en países diversos.
# Acción: Visualizar las diferencias y similitudes.
# Objetivo: Apreciar cómo varían los factores de felicidad entre países muy distintos.
#
# **Cómo:** Se usan las siguientes codificaciones visuales: Encode (Align, Color (Hue)). La posición horizontal representa cada factor, la posición vertical muestra el valor normalizado, y el color diferencia cada país en el gráfico de coordenadas

# %%
# Visualización Nº12                   
df_numerico = df.head(1).select_dtypes(include='number')  

valores = df_numerico.values.flatten()  
#valores = df_numerico.sum()
etiquetas = df_numerico.columns        

plt.pie(
    valores,
    labels=etiquetas,
    autopct='%1.1f%%',
    startangle=90
)
plt.title("Factores del país Top 1")
plt.show()

# %% [markdown]
# **Qué:** Datos categóricos (regiones) y escalares (felicidad).
#
# **Por qué:** Comparar promedios entre distintas regiones.
#
# Tarea: Clasificar y contrastar grupos.
#
# Acción: Las barras agrupan y destacan diferencias.
#
# Objetivo: Ver qué regiones son más o menos felices.
#
# **Cómo:** Barras; posición X = región, altura = valor medio.

# %%
# Visualización Nº13

top_country = df.loc[df['Happiness Rank'] == df['Happiness Rank'].min(), 'Country'].values[0]
features = [
    "Economy (GDP per Capita)", "Family", "Health (Life Expectancy)",
    "Freedom", "Trust (Government Corruption)", "Generosity", "Dystopia Residual"
]
values = df.loc[df['Country'] == top_country, features].values.flatten().tolist()

labels = features
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False)

fig, ax = plt.subplots(figsize=(7,6), subplot_kw=dict(polar=True))
bars = ax.bar(angles, values, width= 0.9, alpha=0.7, edgecolor='black', color = sns.color_palette("Set1", 9))

ax.set_xticks(angles)
ax.set_xticklabels(labels)
plt.title(f'Polar Bar Chart: Factores de {top_country}')
plt.show()

# %% [markdown]
# **Qué:** El tipo de dataset son datos escalares (factores de felicidad del país top 1).
#
# **Por qué:** Mostrar la composición de los factores que contribuyen a la felicidad en el país más feliz.
#
# Tarea: Mostrar los factores de felicidad en el país top 1.
# Acción: Visualizar la magnitud de cada factor.
# Objetivo: Apreciar cómo se distribuyen los distintos factores en el país más feliz.
#
# **Cómo:** Se usan las siguientes codificaciones visuales: Encode (Align, Color (Hue)). La posición angular representa cada factor, la longitud radial muestra el valor de cada factor, y el color diferencia cada barra en el gráfico

# %%
# Visualización Nº14
plt.hist(df['Happiness Score'], bins='auto', color='#ff9819', edgecolor='black')
plt.title("Distribución global del mayor Happiness Score")
plt.xlabel("Happiness Score")
plt.ylabel("Número de países")
plt.show()

# %% [markdown]
# **Qué:** Datos escalares (PIB per cápita y felicidad) con variable categórica (región).
#
# **Por qué:** Mostrar correlación diferenciada por regiones.
#
# Tarea: Correlacionar con comparación de grupos.
#
# Acción: Colores permiten distinguir regiones en la dispersión.
#
# Objetivo: Evaluar si la relación PIB-felicidad varía por región.
#
# **Cómo:** Puntos coloreados; X = PIB, Y = felicidad, color = región.

# %%
# Visualización Nº15

plt.figure(figsize=(14,6))
sns.boxplot(data=df, x='Region', y='Happiness Score', showfliers=True, color='#ffd519')
plt.xticks(rotation=40, ha='right')
plt.title('Boxplot del Happiness Score por Región (medianas y outliers)')
plt.xlabel('Región')
plt.show()

# %% [markdown]
# **Qué:** El tipo de dataset son datos escalares (Happiness Score por región).
#
# **Por qué:** Mostrar la distribución, mediana y presencia de outliers del nivel de felicidad en distintas regiones del mundo.
#
# Tarea: Mostrar la variabilidad y tendencia central del Happiness Score por región.
# Acción: Visualizar la dispersión y los valores atípicos.
# Objetivo: Apreciar cómo se distribuye el nivel de felicidad en cada región y comparar sus rangos y medianas.
#
# **Cómo:** Se usan las siguientes codificaciones visuales: Encode (Align, Color (Hue)). La posición horizontal representa la región, la posición vertical muestra el Happiness Score, y el color diferencia las cajas

# %% [markdown]
# #### **Reflexion final**
#
# Tras un análisis exhaustivo de las visualizaciones generadas, se puede inferir que la variable "Economy (GDP per Capita)" ejerce una influencia considerable sobre el Happiness Score. Se llegó a esta conclusión gracias a la correlación positiva observada en el scatterplot, donde se aprecia una tendencia ascendente entre el ingreso per cápita y el nivel de felicidad reportado. Adicionalmente, al examinar los factores de felicidad en los países con los puntajes más altos, se observa que la "Economy (GDP per Capita)" consistentemente presenta valores elevados, lo que sugiere que un mayor desarrollo económico contribuye significativamente al bienestar general percibido por la población. No obstante, es importante reconocer que la felicidad es un constructo multifactorial y que otras variables, como el apoyo social ("Family"), la salud ("Health (Life Expectancy)") y la libertad ("Freedom"), también desempeñan un papel crucial, aunque la economía parece ser un factor preponderante.
